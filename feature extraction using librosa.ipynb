# %%
# %matplotlib inline  
import librosa as lr
import librosa.display
import IPython
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\naina\\Aexercise\\Technocolabs\\prj1\\provided'

# %%
dir1 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/banjo/")

# %%
len(dir1)

# %%
banjo = pd.DataFrame()

# %%
for i in range(len(dir1)):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/banjo/" + dir1[i]
    audio = path
    y, sr = lr.load(audio)
    secs = np.size(y)/sr 
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    banjo = banjo.append(final_df, ignore_index = True)

# %%
banjo.to_csv('banjo.csv', index = False)

# %%
dir2 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/bass clarinet/")

# %%
len(dir2)
# Out:
# 944

# %%
bass = pd.DataFrame()

# %%
for i in range(len(dir2)):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/bass clarinet/" + dir2[i]
    audio = path
    y, sr = lr.load(audio)
    secs = np.size(y)/sr 
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    bass = bass.append(final_df, ignore_index = True)
# Out:
# C:\Users\naina\AppData\Local\Temp/ipykernel_10392/946876699.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=720
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=360
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=180
#   D = stft(
# C:\Users\naina\AppData\Local\Temp/ipykernel_10392/946876699.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=684
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=342
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=171
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=90
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=45
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=792
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=396
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=198
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=756
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=378
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=189
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=828
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=414
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=207
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=576
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=288
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=972
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=486
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=243
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=648
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=567
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=936
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=558
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=279
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=774
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=387
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=324
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=162
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=900
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=450
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=225
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=612
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=306
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=153
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=522
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=261
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=630
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=315
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=603
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=639
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=594
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=621
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=810
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=405
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=468
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=738
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=369
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=1008
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=540
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=270
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=135
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=504
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=252
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=126
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=234
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=117
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=864
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=432
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=216
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=657
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=531
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=297
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=585
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=549
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=711
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=666
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=693
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=675
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=918
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=459
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=882
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=441
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=729
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=990
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=954
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=477
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=144
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=108
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=495
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=873
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=333
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=846
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=423
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=513
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=909
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=702
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=351
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=1017
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=747
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=945
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=855
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=927
#   D = stft(

# %%
bass.to_csv('bass.csv', index = False)

# %%
dir3 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/bassoon/")

# %%
len(dir3)
# Out:
# 720

# %%
bassoon = pd.DataFrame()

# %%
for i in range(len(dir3)):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/bassoon/" + dir3[i]
    audio = path
    y, sr = lr.load(audio)
    secs = np.size(y)/sr 
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    bassoon = bassoon.append(final_df, ignore_index = True)
# Out:
# C:\Users\naina\AppData\Local\Temp/ipykernel_28760/1118701410.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=864
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=432
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=216
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=108
#   D = stft(
# C:\Users\naina\AppData\Local\Temp/ipykernel_28760/1118701410.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=720
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=360
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=180
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=576
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=288
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=144
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=936
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=468
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=234
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=117
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=1008
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=504
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=252
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=126
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=540
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=270
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=135
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=972
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=486
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=918
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=459
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=792
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=396
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=198
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=99
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=90
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=684
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=342
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=171
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=648
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=324
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=162
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=900
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=450
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=846
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=423
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=81
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=954
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=477
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=882
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=441
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=990
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=495
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=612
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=306
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=153
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=810
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=405
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=513
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=630
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=315
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=774
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=756
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=378
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=189
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=828
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=414
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=387
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=927
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=207
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=531
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=738
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=369
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=1017
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=522
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=747
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=261
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=63
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=567
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=855
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=594
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=711
#   D = stft(

# %%
bassoon.to_csv('bassoon.csv', index = False)

# %%
dir4 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/cello/")

# %%
len(dir4)
# Out:
# 889

# %%
cello = pd.DataFrame()

# %%
for i in range(len(dir4)):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/cello/" + dir4[i]
    audio = path
    y, sr = lr.load(audio)
    secs = np.size(y)/sr 
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    cello = cello.append(final_df, ignore_index = True)
# Out:
# C:\Users\naina\AppData\Local\Temp/ipykernel_28760/3066717855.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=225
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=297
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=783
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=243
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=558
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=279
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=729
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=891
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=621
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=603
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=675
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=666
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=333
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=873
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=765
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=801
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=837
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=702
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=351
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=693
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=819
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=657
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=909
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=963
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=549
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=639
#   D = stft(

# %%
cello.to_csv('cello.csv', index = False)

# %%
dir8 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/double bass/")

# %%
len(dir8)
# Out:
# 852

# %%
dbass = pd.DataFrame()

# %%
for i in range(len(dir8)):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/double bass/" + dir8[i]
    audio = path
    y, sr = lr.load(audio)
    secs = np.size(y)/sr 
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    dbass = dbass.append(final_df, ignore_index = True)
# Out:
# C:\Users\naina\AppData\Local\Temp/ipykernel_28760/278402752.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=585
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\effects.py:95: UserWarning: n_fft=2048 is too small for input signal of length=1728
#   stft = core.stft(y)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\spectrum.py:2538: UserWarning: n_fft=2048 is too small for input signal of length=1728
#   stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=54
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=27
#   D = stft(

# %%
dbass.to_csv('dbass.csv', index = False)

# %%
dir12 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/mandolin/")

# %%
len(dir12)
# Out:
# 80

# %%
mandolin = pd.DataFrame()

# %%
for i in range(len(dir12)):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/mandolin/" + dir12[i]
    audio = path
    y, sr = lr.load(audio)
    secs = np.size(y)/sr 
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    mandolin = mandolin.append(final_df, ignore_index = True)
# Out:
# C:\Users\naina\AppData\Local\Temp/ipykernel_6172/2469665157.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\AppData\Local\Temp/ipykernel_6172/2469665157.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=837
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=855
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=1017
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=963
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=1008
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=999
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=981
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=990
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=747
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=765
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=774
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=972
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=900
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=954
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=792
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=819
#   D = stft(

# %%
mandolin.to_csv('mandolin.csv', index = False)

# %%
dir14 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/saxophone/")

# %%
len(dir14)
# Out:
# 732

# %%
saxophone = pd.DataFrame()

# %%
for i in range(len(dir14)):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/saxophone/" + dir14[i]
    audio = path
    y, sr = lr.load(audio)
    y = y[~(np.isnan(y))]
    if y.size == 0:
        np.delete(y)
        continue
    secs = np.size(y)/sr
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    saxophone = saxophone.append(final_df, ignore_index = True)
# Out:
# C:\Users\naina\AppData\Local\Temp/ipykernel_17484/1649543785.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=720
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=360
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=180
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=90
#   D = stft(
# C:\Users\naina\AppData\Local\Temp/ipykernel_17484/1649543785.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=864
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=432
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=216
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=108
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=756
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=378
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=189
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=936
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=468
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=234
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=1008
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=504
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=252
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=882
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=441
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=972
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=486
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=522
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=261
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=612
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=306
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=900
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=450
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=738
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=369
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=117
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=792
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=396
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=198
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=99
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=594
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=297
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=243
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=666
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=333
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=540
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=270
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=225
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=918
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=459
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=810
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=828
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=153
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=648
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=324
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=414
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=558
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=279
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=846
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=423
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=405
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=162
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=81
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=207
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=774
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=387
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=576
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=288
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=144
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=72
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=126
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=684
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=342
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=990
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=495
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=891
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=927
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=630
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=315
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=702
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=351
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=171
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=135
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=639
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=1017
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=837
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=675
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=819
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=954
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=477
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=801
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=999
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=945
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=711
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=765
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=783
#   D = stft(

# %%
saxophone.to_csv('saxophone.csv', index = False)

# %%
dir17 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/trumpet/")

# %%
len(dir17)
# Out:
# 485

# %%
trumpet = pd.DataFrame()

# %%
for i in range(len(dir17)):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/trumpet/" + dir17[i]
    audio = path
    y, sr = lr.load(audio)
    secs = np.size(y)/sr 
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    trumpet = trumpet.append(final_df, ignore_index = True)
# Out:
# C:\Users\naina\AppData\Local\Temp/ipykernel_6172/601455369.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=783
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=945
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=513
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=603
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=531
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=873
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=693
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=549
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=909
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=729
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=657
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=585
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=567
#   D = stft(

# %%
trumpet.to_csv('trumpet.csv', index = False)

# %%
dir19 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/violin/")

# %%
len(dir19)
# Out:
# 1488

# %%
violin = pd.DataFrame()

# %%
for i in range(1001, 1488):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/violin/" + dir19[i]
    audio = path
    y, sr = lr.load(audio)
    y = y[~(np.isnan(y))]
    if y == []:
        np.delete(y)
        continue
    secs = np.size(y)/sr
    #secs = secs[~(np.isnan(secs))]
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    violin = violin.append(final_df, ignore_index = True)

# %%
violin.to_csv('violin_part3.csv', index = False)

# %%
violin.shape
# Out:
# (500, 74)

# %%
trumpet.to_csv('trumpet.csv', index = False)

# %%
dir20 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/all-percussion/")

# %%
len(dir20)
# Out:
# 148

# %%
#ddd = pd.read_csv("")

# %%
for i in range(len(dir20)):
    train_data.isnull().sum()

# %%
allper = pd.DataFrame()

# %%
for i in range(len(dir20)):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/all-percussion/" + dir20[i]
    audio = path
    y, sr = lr.load(audio)
    secs = np.size(y)/sr 
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    allper = allper.append(final_df, ignore_index = True)
# Out:
# C:\Users\naina\AppData\Local\Temp/ipykernel_28568/1549634044.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = lr.load(audio)
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=513
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\pitch.py:98: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=765
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=531
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=711
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=729
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=657
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=549
#   D = stft(
# C:\Users\naina\anaconda3\lib\site-packages\librosa\core\constantq.py:1142: UserWarning: n_fft=1024 is too small for input signal of length=981
#   D = stft(

# %%
allper.to_csv('allper.csv', index = False)

# %%
dir18 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/viola/")

# %%
len(dir18)
# Out:
# 974

# %%
dir18[40]
# Out:
# 'viola_A4_1_piano_arco-glissando.mp3'

# %%
viola = pd.DataFrame()

# %%
for i in range(705, 974):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/viola/" + dir18[i]
    audio = path
    y, sr = lr.load(audio)
    y = y[~(np.isnan(y))]
    if y == []:
        np.delete(y)
        continue
    secs = np.size(y)/sr
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    viola = viola.append(final_df, ignore_index = True)

# %%
viola.shape
# Out:
# (269, 74)

# %%
viola.to_csv('viola_part5.csv', index = False)

# %%
dir17 = os.listdir("C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/tuba/")

# %%
len(dir17)
# Out:
# 972

# %%
dir17[40]
# Out:
# 'tuba_A2_1_forte_normal.mp3'

# %%
tuba = pd.DataFrame()

# %%
for i in range(288, 400):
    path = "C:/Users/naina/Aexercise/Technocolabs/prj1/provided/all sample extracted/tuba/" + dir17[i]
    audio = path
    y, sr = lr.load(audio)
    y = y[~(np.isnan(y))]
    if y == []:
        np.delete(y)
        continue
    secs = np.size(y)/sr
    
    y_harmonic, y_percussive = lr.effects.hpss(y)
    tempo, beat_frames = lr.beat.beat_track(y=y_harmonic, sr=sr)
    beat_times = lr.frames_to_time(beat_frames, sr=sr)
    beat_time_diff = np.ediff1d(beat_times)
    beat_nums = np.arange(1, np.size(beat_times))
    chroma = lr.feature.chroma_cens(y=y_harmonic, sr=sr)
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sr, n_mfcc=13)
    cent = lr.feature.spectral_centroid(y=y, sr=sr)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sr)
    rolloff = lr.feature.spectral_rolloff(y=y, sr=sr)
    zrate=librosa.feature.zero_crossing_rate(y_harmonic)
    chroma_mean=np.mean(chroma,axis=1)
    chroma_std=np.std(chroma,axis=1)
    
    chroma_df=pd.DataFrame()
    for i in range(0,12):
        chroma_df['chroma_mean_'+str(i)]=chroma_mean[i]
    for i in range(0,12):
        chroma_df['chroma_std_'+str(i)]=chroma_mean[i]
    chroma_df.loc[0]=np.concatenate((chroma_mean,chroma_std),axis=0)
    
    mfccs_mean=np.mean(mfccs,axis=1)
    mfccs_std=np.std(mfccs,axis=1)
    coeffs=np.arange(0,13)
    mfccs_df=pd.DataFrame()
    for i in range(0,13):
        mfccs_df['mfccs_mean_'+str(i)]=mfccs_mean[i]
    for i in range(0,13):
        mfccs_df['mfccs_std_'+str(i)]=mfccs_mean[i]
    mfccs_df.loc[0]=np.concatenate((mfccs_mean,mfccs_std),axis=0)
    cent_mean=np.mean(cent)
    cent_std=np.std(cent)
    cent_skew=scipy.stats.skew(cent,axis=1)[0]
    contrast_mean=np.mean(contrast,axis=1)
    contrast_std=np.std(contrast,axis=1)
    conts=np.arange(0,7)
    contrast_df=pd.DataFrame()
    rolloff_mean=np.mean(rolloff)
    rolloff_std=np.std(rolloff)
    rolloff_skew=scipy.stats.skew(rolloff,axis=1)[0]
    spectral_df=pd.DataFrame()
    collist=['cent_mean','cent_std','cent_skew']
    for i in range(0,7):
        collist.append('contrast_mean_'+str(i))
    for i in range(0,7):
        collist.append('contrast_std_'+str(i))
    collist=collist+['rolloff_mean','rolloff_std','rolloff_skew']
    for c in collist:
        spectral_df[c]=0
    data=np.concatenate(([cent_mean,cent_std,cent_skew],contrast_mean,contrast_std,[rolloff_mean,rolloff_std,rolloff_std]),axis=0)
    spectral_df.loc[0]=data
    zrate_mean=np.mean(zrate)
    zrate_std=np.std(zrate)
    zrate_skew=scipy.stats.skew(zrate,axis=1)[0]   
    zrate_df=pd.DataFrame()
    zrate_df['zrate_mean']=0
    zrate_df['zrate_std']=0
    zrate_df['zrate_skew']=0
    zrate_df.loc[0]=[zrate_mean,zrate_std,zrate_skew]
    beat_df=pd.DataFrame()
    beat_df['tempo']=tempo
    beat_df.loc[0]=tempo
   
    final_df = pd.concat((chroma_df, mfccs_df, spectral_df, zrate_df, beat_df), axis = 1)
    tuba = tuba.append(final_df, ignore_index = True)

# %%
tuba.shape
# Out:
# (112, 74)

# %%
tuba.to_csv('tuba_part2.csv', index = False)
